# %%
from env import host, username, password

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pydataset import data
import seaborn as sns

# %%
iris = sns.load_dataset('iris')

iris.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 0             5.1          3.5           1.4          0.2      setosa
# 1             4.9          3.0           1.4          0.2      setosa
# 2             4.7          3.2           1.3          0.2      setosa
# 3             4.6          3.1           1.5          0.2      setosa
# 4             5.0          3.6           1.4          0.2      setosa
# 5             5.4          3.9           1.7          0.4      setosa
# 6             4.6          3.4           1.4          0.3      setosa
# 7             5.0          3.4           1.5          0.2      setosa
# 8             4.4          2.9           1.4          0.2      setosa
# 9             4.9          3.1           1.5          0.1      setosa
# 10            5.4          3.7           1.5          0.2      setosa
# 11            4.8          3.4           1.6          0.2      setosa
# ...

# %% [markdown]
# # What does the distribution of petal lengths look like?

# %%
sns.histplot(iris.petal_length,kde=True)
# Out:
# <AxesSubplot:xlabel='petal_length', ylabel='Count'>

# %% [markdown]
# # Is there a correlation between petal length and petal width? Use http://guessthecorrelation.com/ as a hint to how we could # visually determine if a correlation exists between two numeric columns.

# %%
sns.relplot(x = "petal_length", y = "petal_width", data = iris)

# %%
# yes! the correlation is the longer the pedal is, the wider the petal becomes

# %% [markdown]
# # Would it be reasonable to predict species based on sepal width and sepal length? For this, you'll visualize two numeric columns through the lense of a categorical column.

# %%
sns.relplot(x = "sepal_length", y = "sepal_width", hue = "species", data = iris)

# %%
# I would say not the best measure of category but! it does look like the setosa species seem to be correlated to shorter sepal lengths while having wider sepal lengths.

# %% [markdown]
# # Which features would be best used to predict species?

# %%
sns.pairplot(iris,hue = "species")

# %% [markdown]
# '''
# some of the best things to look at:
# (1,3)
# (1,4)
# (2,3)
# (2,4)
# (3,1)
# (3,2)
# (3,4)
# (4,1)
# (4,2)
# (4,3)
# '''
# according to the pairplot, in regards to species, looking at these individuals graphs above '(row,col)', these show the biggest correlation in identifying species with some tolerance

# %% [markdown]
# # Using the lesson as an example, use seaborn's load_dataset function to load the anscombe data set. Use pandas to group the data by the dataset column, and calculate summary statistics for each dataset. What do you notice?

# %%
anscombe = sns.load_dataset('anscombe')

anscombe.dtypes
# Out:
# dataset     object
# x          float64
# y          float64
# dtype: object

# %%
anscombe.head()
# Out:
#   dataset     x     y
# 0       I  10.0  8.04
# 1       I   8.0  6.95
# 2       I  13.0  7.58
# 3       I   9.0  8.81
# 4       I  11.0  8.33

# %%
anscombe.describe()
# Out:
#                x          y
# count  44.000000  44.000000
# mean    9.000000   7.500682
# std     3.198837   1.958925
# min     4.000000   3.100000
# 25%     7.000000   6.117500
# 50%     8.000000   7.520000
# 75%    11.000000   8.747500
# max    19.000000  12.740000

# %%
# the data points are very similar. the dataset columns makes me think that these were all separate data frames merged

# %% [markdown]
# # Plot the x and y values from the anscombe data. Each dataset should be in a separate column.

# %%
sns.relplot(x='x', y='y', col="dataset", data=anscombe)

# %% [markdown]
# # Load the InsectSprays dataset and read it's documentation. Create a boxplot that shows the effectiveness of the different insect sprays

# %%
insectsprays = sns.load_dataset('insect_sprays')

insectsprays.dtypes
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/d0/5dr5q0n145vcn3_m9dxy1xq80000gn/T/ipykernel_28638/4004959060.py in <module>
# ----> 1 insectsprays = sns.load_dataset('insect_sprays')
#       2
#       3 insectsprays.dtypes
#
# /usr/local/anaconda3/lib/python3.9/site-packages/seaborn/utils.py in load_dataset(name, cache, data_home, **kws)
#     593         if not os.path.exists(cache_path):
#     594             if name not in get_dataset_names():
# --> 595                 raise ValueError(f"'{name}' is not one of the example datasets.")
#     596             urlretrieve(url, cache_path)
#     597         full_path = cache_path
#
# ValueError: 'insect_sprays' is not one of the example datasets.

# %%
sns.get_dataset_names()

# %%
insectsprays= data('InsectSprays')

# %%
data("InsectSprays", show_doc = True)

# %%
insectsprays.head()

# %%
sns.boxplot(data=insectsprays, x = 'spray',y = "count")
plt.title("$count$ $of$ $victims$ $per$ $spray$")

# %% [markdown]
# # Load the swiss dataset and read it's documentation. The swiss dataset is available from pydatset rather than seaborn. Create visualizations to answer the following questions:

# %%
swiss = data('swiss')

# %%
swiss.head()

# %% [markdown]
# # Create an attribute named is_catholic that holds a boolean value of whether or not the province is Catholic. (Choose a cutoff point for what constitutes catholic)

# %%
swiss.dtypes

# %%
 swiss['is_catholic'] = np.where(swiss.Catholic >= 50,"is_catholic", "other_religon")

# %%
swiss.head()

# %%
sns.relplot(y = "Fertility", x = "Catholic",hue = "is_catholic",data= swiss )

# %%
# it does seem like the higher rates are held by catholic region but numbers arent overwhelmingly yes. look at the outliers

# %%
sns.pairplot(swiss)

# %%
# if you look at infant mortality,education, examination those seem to have the strongest linear correlation

# %%
def get_db_url(host, username, password, db):
    
    '''
    return a formatted string containing username,
    password, host and db for MySQL SERVER AND DB.
    The env_file check to see if the env.py exist in current working directory
    
    '''
    return f'mysql+pymysql://{username}:{password}@{host}/{db}'

# %%
url = get_db_url(host, username, password, 'chipotle')

# %%
query = 'SELECT * FROM orders'

# %%
orders = pd.read_sql(query,url)

# %%
orders['item_price'] = orders.item_price.str.replace('$','').str.replace('.','').astype(float)
# Out:
# /var/folders/d0/5dr5q0n145vcn3_m9dxy1xq80000gn/T/ipykernel_28638/151468850.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   orders['item_price'] = orders.item_price.str.replace('$','').str.replace('.','').astype(float)

# %%
orders['revenue'] = orders['item_price'] * orders['quantity']

# %%
orders['revenue'].nlargest(4)
# Out:
# 3598    66375.0
# 4152    15000.0
# 1254    14000.0
# 3602    14000.0
# Name: revenue, dtype: float64

# %%
chipotle = orders.groupby('item_name').agg('max').sort_values(by='quantity', ascending=False).head(4).reset_index()

sns.barplot(x ='item_name', y='revenue', data = chipotle)

plt.title("$ Big$ $Four$")
plt.xticks(rotation = 80)
# Out:
# (array([0, 1, 2, 3]),
#  [Text(0, 0, 'Chips and Fresh Tomato Salsa'),
#   Text(1, 0, 'Bottled Water'),
#   Text(2, 0, 'Side of Chips'),
#   Text(3, 0, 'Chips and Guacamole')])

# %%
# Load the sleepstudy data and read it's documentation. Use seaborn to create a line chart of all the individual subject's reaction times and a more prominant line showing the average change in reaction time.
sleepstudy = data('sleepstudy')

data('sleepstudy', show_doc=True)
# Out:
# sleepstudy
#
# PyDataset Documentation (adopted from R Documentation. The displayed examples are in R)
#
# ## Reaction times in a sleep deprivation study
#
# ### Description
#
# The average reaction time per day for subjects in a sleep deprivation study.
# On day 0 the subjects had their normal amount of sleep. Starting that night
# they were restricted to 3 hours of sleep per night. The observations represent
# the average reaction time on a series of tests given each day to each subject.
#
# ### Format
#
# A data frame with 180 observations on the following 3 variables.
#
# `Reaction`
#
# Average reaction time (ms)
#
# `Days`
#
# Number of days of sleep deprivation
#
# `Subject`
#
# Subject number on which the observation was made.
#
# ### Details
#
# These data are from the study described in Belenky et al. (2003), for the
# sleep-deprived group and for the first 10 days of the study, up to the
# recovery period.
#
# ### References
#
# ...

# %%
sleepstudy.Subject = sleepstudy.Subject.astype(str)

# %%
sns.lineplot(x='Subject', y='Reaction',data = sleepstudy)
plt.xlabel('$Ind.$ $Subjects$')
plt.ylabel('$reaction$ $time$ $throughout$ $days$')
# Out:
# Text(0, 0.5, '$reaction$ $time$ $throughout$ $days$')
