# %% [markdown]
# # Use matplotlib to plot the following equation:

# %%
import matplotlib.pyplot as plt
from importlib import reload
plt=reload(plt)

# %%
import numpy as np
import matplotlib.pyplot as plt
import math

# %matplotlib inline

# %%
x = range(-100,100)
y =[(num**2 - num + 2) for num in x]

# %%
x
# Out:
# range(-100, 100)

# %%
y
# Out:
# [10102,
#  9902,
#  9704,
#  9508,
#  9314,
#  9122,
#  8932,
#  8744,
#  8558,
#  8374,
#  8192,
#  8012,
#  7834,
#  7658,
#  7484,
#  7312,
#  7142,
#  6974,
#  6808,
#  6644,
#  6482,
#  6322,
#  6164,
#  6008,
#  5854,
#  5702,
#  5552,
#  5404,
#  5258,
#  5114,
#  4972,
#  4832,
#  4694,
#  4558,
#  4424,
#  4292,
#  4162,
#  4034,
#  3908,
#  3784,
#  3662,
#  3542,
#  3424,
#  3308,
#  3194,
#  3082,
#  2972,
#  2864,
#  2758,
#  2654,
#  2552,
#  2452,
#  2354,
#  2258,
#  2164,
#  2072,
#  1982,
#  1894,
#  1808,
#  1724,
#  1642,
#  1562,
#  1484,
#  1408,
#  1334,
#  1262,
#  1192,
#  1124,
#  1058,
#  994,
#  932,
#  872,
#  814,
#  758,
#  704,
#  652,
#  602,
#  554,
#  508,
#  464,
#  422,
#  382,
#  344,
#  308,
#  274,
#  242,
#  212,
#  184,
#  158,
#  134,
#  112,
#  92,
#  74,
#  58,
#  44,
#  32,
#  22,
#  14,
#  8,
#  4,
#  2,
#  2,
#  4,
#  8,
#  14,
#  22,
#  32,
#  44,
#  58,
#  74,
#  92,
#  112,
#  134,
#  158,
#  184,
#  212,
#  242,
#  274,
#  308,
#  344,
#  382,
#  422,
#  464,
#  508,
#  554,
#  602,
#  652,
#  704,
#  758,
#  814,
#  872,
#  932,
#  994,
#  1058,
#  1124,
#  1192,
#  1262,
#  1334,
#  1408,
#  1484,
#  1562,
#  1642,
#  1724,
#  1808,
#  1894,
#  1982,
#  2072,
#  2164,
#  2258,
#  2354,
#  2452,
#  2552,
#  2654,
#  2758,
#  2864,
#  2972,
#  3082,
#  3194,
#  3308,
#  3424,
#  3542,
#  3662,
#  3784,
#  3908,
#  4034,
#  4162,
#  4292,
#  4424,
#  4558,
#  4694,
#  4832,
#  4972,
#  5114,
#  5258,
#  5404,
#  5552,
#  5702,
#  5854,
#  6008,
#  6164,
#  6322,
#  6482,
#  6644,
#  6808,
#  6974,
#  7142,
#  7312,
#  7484,
#  7658,
#  7834,
#  8012,
#  8192,
#  8374,
#  8558,
#  8744,
#  8932,
#  9122,
#  9314,
#  9508,
#  9704]

# %%
plt.title("$y^2$ $- x + 2$ ")
plt.plot(x,y)
plt.annotate(text = 'arrow', xy=(0,0),xytext=(6,400),arrowprops ={'width':2})
# Out:
# Text(6, 400, 'arrow')

# %% [markdown]
# # Create and label 4 separate charts for the following equations (choose a range for x that makes sense):

# %%
x1 = range(1,30)

x1
# Out:
# range(1, 30)

# %%
y1 = [math.sqrt(n)for n in x1]

y1
# Out:
# [1.0,
#  1.4142135623730951,
#  1.7320508075688772,
#  2.0,
#  2.23606797749979,
#  2.449489742783178,
#  2.6457513110645907,
#  2.8284271247461903,
#  3.0,
#  3.1622776601683795,
#  3.3166247903554,
#  3.4641016151377544,
#  3.605551275463989,
#  3.7416573867739413,
#  3.872983346207417,
#  4.0,
#  4.123105625617661,
#  4.242640687119285,
#  4.358898943540674,
#  4.47213595499958,
#  4.58257569495584,
#  4.69041575982343,
#  4.795831523312719,
#  4.898979485566356,
#  5.0,
#  5.0990195135927845,
#  5.196152422706632,
#  5.291502622129181,
#  5.385164807134504]

# %%
plt.title("y = $sqrt(x)$")
plt.plot(x1,y1)

# %%
z = [(n**3) for n in x1]
z
# Out:
# [1,
#  8,
#  27,
#  64,
#  125,
#  216,
#  343,
#  512,
#  729,
#  1000,
#  1331,
#  1728,
#  2197,
#  2744,
#  3375,
#  4096,
#  4913,
#  5832,
#  6859,
#  8000,
#  9261,
#  10648,
#  12167,
#  13824,
#  15625,
#  17576,
#  19683,
#  21952,
#  24389]

# %%
plt.plot(x1,z)
plt.title("y=$x^3$")
# Out:
# Text(0.5, 1.0, 'y=$x^3$')

# %%
a = [(2**n)for n in x1]
a
# Out:
# [2,
#  4,
#  8,
#  16,
#  32,
#  64,
#  128,
#  256,
#  512,
#  1024,
#  2048,
#  4096,
#  8192,
#  16384,
#  32768,
#  65536,
#  131072,
#  262144,
#  524288,
#  1048576,
#  2097152,
#  4194304,
#  8388608,
#  16777216,
#  33554432,
#  67108864,
#  134217728,
#  268435456,
#  536870912]

# %%
plt.plot(x1,a)
plt.title('$y = pow(2,x)$')
# Out:
# Text(0.5, 1.0, '$y = pow(2,x)$')

# %%
b = [1/(n+1) for n in x1]
b
# Out:
# [0.5,
#  0.3333333333333333,
#  0.25,
#  0.2,
#  0.16666666666666666,
#  0.14285714285714285,
#  0.125,
#  0.1111111111111111,
#  0.1,
#  0.09090909090909091,
#  0.08333333333333333,
#  0.07692307692307693,
#  0.07142857142857142,
#  0.06666666666666667,
#  0.0625,
#  0.058823529411764705,
#  0.05555555555555555,
#  0.05263157894736842,
#  0.05,
#  0.047619047619047616,
#  0.045454545454545456,
#  0.043478260869565216,
#  0.041666666666666664,
#  0.04,
#  0.038461538461538464,
#  0.037037037037037035,
#  0.03571428571428571,
#  0.034482758620689655,
#  0.03333333333333333]

# %%
plt.plot(x1,b)
plt.title("$1/(x+1)$")
# Out:
# Text(0.5, 1.0, '$1/(x+1)$')

# %% [markdown]
# # combine the figures you created in the last step into one large figure with 4 subplots.

# %%
fig, axs = plt.subplots(2, 2)

axs[0, 0].plot(x1, y1)
axs[0, 0].set_title('Axis [0, 0], sqrt(x)')

axs[0, 1].plot(x1, z, 'tab:orange')
axs[0, 1].set_title('Axis [0, 1], x^3')

axs[1, 0].plot(x1, a, 'tab:green')
axs[1, 0].set_title('Axis [1, 0],2^x')

axs[1, 1].plot(x1, b, 'tab:red')
axs[1, 1].set_title('Axis [1, 1],1/(x+1)')
# Out:
# Text(0.5, 1.0, 'Axis [1, 1],1/(x+1)')

# %% [markdown]
# # Combine the figures you created in the last step into one figure where each of the 4 equations has a different color for the points. Be sure to include a legend and an appropriate title for the figure.

# %%
plt.plot(x1,y1, label = " $sqrt(x)$ ")
plt.plot(x1,z, label = " $x^3$ ")
plt.plot(x1,a, label = " $2^x$")
plt.plot(x1,b, label = " $1/(x+1)$ ")

plt.ylim(0,40)

plt.legend(loc='upper right')
